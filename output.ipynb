# %%
# When working in AI LRZ
# %cd ~/cma/CMA_Fairness_v2
# Out:
# /dss/dsshome1/0C/ra93lal2/cma/CMA_Fairness_v2
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
print(os.getcwd())
# Out:
# /dss/dsshome1/0C/ra93lal2/cma/CMA_Fairness_v2

# %%
import pandas as pd
from pathlib import Path
import gzip

# %% [markdown]
# Adjust the run number to match the desired run output

# %%
# Set path to output folder
data_dir = Path("./output/runs/1/data")

# %%
# Load and inspect the aggregated output
df_agg = pd.read_csv(data_dir / "agg_1_run_outputs.csv.gz")
print("Aggregated output shape:", df_agg.shape)
df_agg.head()
# Out:
# Aggregated output shape: (3600, 51)
#    Unnamed: 0  run_no                       universe_id  \
# 0           0      14  616b0cf572a2e986c1ac91d47f0fe181
# 1           1      14  616b0cf572a2e986c1ac91d47f0fe181
# 2           2      14  616b0cf572a2e986c1ac91d47f0fe181
# 3           3      14  616b0cf572a2e986c1ac91d47f0fe181
# 4           4      14  e7b3e337360cf7d4d088ff6da9af52e6
#
#                                    universe_settings  execution_time  \
# 0  {"cutoff": "quantile_0.1", "eval_fairness_grou...       38.670904
# 1  {"cutoff": "quantile_0.1", "eval_fairness_grou...       38.670904
# 2  {"cutoff": "quantile_0.25", "eval_fairness_gro...       38.670904
# 3  {"cutoff": "quantile_0.25", "eval_fairness_gro...       38.670904
# 4  {"cutoff": "quantile_0.1", "eval_fairness_grou...       31.629141
#
#    test_size_n  test_size_frac  fair_main_equalized_odds_difference  \
# 0        89710             1.0                             0.050354
# ...

# %%
csv_files = sorted(data_dir.glob("d_1_*.csv"))
print(f"Found {len(csv_files)} universe-level output files")
# Out:
# Found 900 universe-level output files

# %%
universe_dfs = {
    f.stem: pd.read_csv(f) for f in csv_files
}

# %%
# Preview one sample
sample_key = list(universe_dfs.keys())[0]
universe_dfs[sample_key].head()
# Out:
#    run_no                       universe_id  \
# 0      14  00ae6aafdb8abc641af0afab496fcc8e
# 1      14  00ae6aafdb8abc641af0afab496fcc8e
# 2      14  00ae6aafdb8abc641af0afab496fcc8e
# 3      14  00ae6aafdb8abc641af0afab496fcc8e
#
#                                    universe_settings  execution_time  \
# 0  {"cutoff": "quantile_0.1", "eval_fairness_grou...       32.309571
# 1  {"cutoff": "quantile_0.1", "eval_fairness_grou...       32.309571
# 2  {"cutoff": "quantile_0.25", "eval_fairness_gro...       32.309571
# 3  {"cutoff": "quantile_0.25", "eval_fairness_gro...       32.309571
#
#    test_size_n  test_size_frac  fair_main_equalized_odds_difference  \
# 0        89710             1.0                             0.016321
# 1        89710             1.0                             0.016321
# 2        89710             1.0                             0.039829
# 3        89710             1.0                             0.039829
#
# ...
