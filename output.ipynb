# %%
import pandas as pd
from pathlib import Path
import gzip

# %%
# Set path to output folder
data_dir = Path("./output/runs/1/data")

# %%
# Load and inspect the aggregated output
df_agg = pd.read_csv(data_dir / "agg_1_run_outputs.csv.gz")
print("Aggregated output shape:", df_agg.shape)
df_agg.head()
# Out:
# Aggregated output shape: (128, 51)
#    Unnamed: 0  run_no                       universe_id  \
# 0           0       1  1a046868f549224919d5aea86afcaf91
# 1           1       1  1a046868f549224919d5aea86afcaf91
# 2           2       1  1a046868f549224919d5aea86afcaf91
# 3           3       1  1a046868f549224919d5aea86afcaf91
# 4           4       1  aeda81ea848062c8b09ab80466cf07c3
#
#                                    universe_settings  execution_time  \
# 0  {"cutoff": "quantile_0.1", "eval_fairness_grou...       22.449074
# 1  {"cutoff": "quantile_0.1", "eval_fairness_grou...       22.449074
# 2  {"cutoff": "quantile_0.25", "eval_fairness_gro...       22.449074
# 3  {"cutoff": "quantile_0.25", "eval_fairness_gro...       22.449074
# 4  {"cutoff": "quantile_0.1", "eval_fairness_grou...      174.308044
#
#    test_size_n  test_size_frac  fair_main_equalized_odds_difference  \
# 0        89710             1.0                             0.044048
# 1        89710             1.0                             0.044048
# 2        89710             1.0                             0.085229
# 3        89710             1.0                             0.085229
# 4        89710             1.0                             0.147376
#
#    fair_main_equalized_odds_ratio  fair_main_demographic_parity_difference  \
# 0                        0.952963                                 0.044510
# 1                        0.952963                                 0.044510
# 2                        0.910254                                 0.064964
# 3                        0.910254                                 0.064964
# 4                        0.852624                                 0.129695
#
#    ...  perf_grp_precision_0  perf_grp_precision_1  \
# 0  ...                   NaN                   NaN
# 1  ...              0.122124              0.138954
# 2  ...                   NaN                   NaN
# 3  ...              0.142143              0.163804
# 4  ...                   NaN                   NaN
#
#    perf_grp_false positive rate_0  perf_grp_false positive rate_1  \
# 0                             NaN                             NaN
# 1                        0.892417                        0.936465
# 2                             NaN                             NaN
# 3                        0.679837                        0.738131
# 4                             NaN                             NaN
#
#    perf_grp_false negative rate_0  perf_grp_false negative rate_1  \
# 0                             NaN                             NaN
# 1                        0.047297                        0.007440
# 2                             NaN                             NaN
# 3                        0.135557                        0.050328
# 4                             NaN                             NaN
#
#    perf_grp_selection rate_0  perf_grp_selection rate_1  perf_grp_count_0  \
# 0                        NaN                        NaN               NaN
# 1                   0.899367                   0.943877           20540.0
# 2                        NaN                        NaN               NaN
# 3                   0.701120                   0.766084           20540.0
# 4                        NaN                        NaN               NaN
#
#    perf_grp_count_1
# 0               NaN
# 1           69170.0
# 2               NaN
# 3           69170.0
# 4               NaN
#
# [5 rows x 51 columns]

# %%
csv_files = sorted(data_dir.glob("d_1_*.csv"))
print(f"Found {len(csv_files)} universe-level output files")
# Out:
# Found 32 universe-level output files

# %%
universe_dfs = {
    f.stem: pd.read_csv(f) for f in csv_files
}

# %%
# Preview one sample
sample_key = list(universe_dfs.keys())[0]
universe_dfs[sample_key].head()
# Out:
#    run_no                       universe_id  \
# 0       1  027bf915af12d3f79f06c5867c0eddfb
# 1       1  027bf915af12d3f79f06c5867c0eddfb
# 2       1  027bf915af12d3f79f06c5867c0eddfb
# 3       1  027bf915af12d3f79f06c5867c0eddfb
#
#                                    universe_settings  execution_time  \
# 0  {"cutoff": "quantile_0.1", "eval_fairness_grou...       16.861576
# 1  {"cutoff": "quantile_0.1", "eval_fairness_grou...       16.861576
# 2  {"cutoff": "quantile_0.25", "eval_fairness_gro...       16.861576
# 3  {"cutoff": "quantile_0.25", "eval_fairness_gro...       16.861576
#
#    test_size_n  test_size_frac  fair_main_equalized_odds_difference  \
# 0        89710             1.0                             0.062964
# 1        89710             1.0                             0.062964
# 2        89710             1.0                             0.091829
# 3        89710             1.0                             0.091829
#
#    fair_main_equalized_odds_ratio  fair_main_demographic_parity_difference  \
# 0                        0.932736                                 0.060976
# 1                        0.932736                                 0.060976
# 2                        0.903461                                 0.074861
# 3                        0.903461                                 0.074861
#
#    fair_main_demographic_parity_ratio  ...  perf_grp_precision_0  \
# 0                            0.935366  ...                   NaN
# 1                            0.935366  ...              0.124634
# 2                            0.902469  ...                   NaN
# 3                            0.902469  ...              0.143028
#
#    perf_grp_precision_1  perf_grp_false positive rate_0  \
# 0                   NaN                             NaN
# 1              0.138886                        0.873101
# 2                   NaN                             NaN
# 3              0.163753                        0.670977
#
#    perf_grp_false positive rate_1  perf_grp_false negative rate_0  \
# 0                             NaN                             NaN
# 1                        0.936065                        0.046030
# 2                             NaN                             NaN
# 3                        0.739597                        0.140625
#
#    perf_grp_false negative rate_1  perf_grp_selection rate_0  \
# 0                             NaN                        NaN
# 1                        0.008425                   0.882425
# 2                             NaN                        NaN
# 3                        0.048796                   0.692697
#
#    perf_grp_selection rate_1  perf_grp_count_0  perf_grp_count_1
# 0                        NaN               NaN               NaN
# 1                   0.943400           20540.0           69170.0
# 2                        NaN               NaN               NaN
# 3                   0.767558           20540.0           69170.0
#
# [4 rows x 50 columns]
